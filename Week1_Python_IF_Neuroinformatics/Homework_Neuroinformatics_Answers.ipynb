# %% [markdown]
# <center><font size = "10"> Week 2 - Neuroscience Datasets<center>
# <center><font size = "8"> Homework ANSWERS<center>

# %% [markdown]
# ## Ex2.1. Morphologies
#
# <font size='3'> Go to [NeuroMorpho.Org](https://neuromorpho.org/) and answer the following questions:
#
#     A) How many Siberian tiger neurons are available? Which brain region are they from?
#     B) How many experiments have a protocol in ovo? Is the Shepherds-crook-neuron a principal cell?
#
#     C) How many interneurons showing either parvalbumin or somatostatin are there in the hippocampus CA1? What about in any of the CA regions?
#     D) Tissue shrinkage can be a serious problem. How many morphologies report it? How many correct for it?
#
#     E) What is the highest slice thickness reported (in millimetres)? Are these central nervous system cells?
#     F) Is there a Hungarian file format? How about a Viking one?
#
#     G) Hippocampus CA is made up of the subfields CA1 + CA2 + CA3. Try answering question C again. What number do you get now? Why is that?
#        Write your reply (do not change your answer to C, it's ok). Remember: it can be dangerous to use wildcards... they are wild!
#
# <font size='3'> Fill in your answers in the dictionary below. Format is already in place, <font color= 'red'>only</font> change the contents.

# %%
answers = {}

answers['morphologies_A'] = (0, 'brain_region')
answers['morphologies_B'] = (0, True or False )
   
answers['morphologies_C'] = (0, 0)
answers['morphologies_D'] = (0, 0)
    
answers['morphologies_E'] = (0, True or False)
answers['morphologies_F'] = (True or False, True or False)
    
answers['morphologies_G'] = (0, 'Write your reply here')

# %%
correct_answers = {}

correct_answers['morphologies_A'] = (33, 'cerebellum')
correct_answers['morphologies_B'] = (1, True)
      
correct_answers['morphologies_C'] = ('(151, 810) with keyword search and CA* wildcard','(151, 203) with keyword search only','(48, 81) with metadata multiple selection','(140,191) with API','we accept all values, the point is to show that query strategy matters and interacting with datasets is not straightforward')
correct_answers['morphologies_D'] = (7029 + 11633, 7029)
    
correct_answers['morphologies_E'] = (5, False)
correct_answers['morphologies_F'] = (False, True)
    
correct_answers['morphologies_G'] = (203, 'CA* includes other text fields unrelated with the hippocampus', 'other ok values include 81, 191 (see 1C), again this answer is considered correct whatever the strategy')

# %% [markdown]
# ## Ex2.2. Ion Channels
#
# <font size='3'> Given what you learned from [Channelpedia](https://channelpedia.epfl.ch/) and the [Kv3.3 channel](https://channelpedia.epfl.ch/wikipages/13), ask yourself:
#
#     A) When you read ANY experiment reporting neural traces/activity/dynamics what is one key factor you should immediately look for in the methods?
#     B) What about in vivo studies that sometimes don't report it explicitly?

# %%
answers['ion_channels_A'] = 'Write your reply here'
answers['ion_channels_B'] = 'Write your reply here'

# %%
correct_answers['ion_channels_A'] = 'Temperature! It greatly affects results'
correct_answers['ion_channels_B'] = 'It is core body temperature ~[36, 36.5] C. Have a look at https://doi.org/10.1007/s10544-015-0028-9'

# %% [markdown]
# ## Ex2.3. Brain atlases
#
# <font size='3'> Go the [Allen Brain Atlas portal](http://atlas.brain-map.org/) and answer the following questions:
#
#     Adult Mouse
#     A) How many specimens were used to create the latest adult mouse atlas?
#     B) What is the reason/purpose behind that?
#     C) Does this also mean there are caveats you should remember when consulting it?
#
#     Adult Human
#     D) How many specimens were used to create the adult human atlas? What age on average (in years)?
#     E) Therefore we need to keep in mind __________ differences and ___ differences may play a role, particularly in certain regions. ___ is of course a factor as well.
#     F) What is another tissue-handling artefact that has a higher impact in very low n cases? Did you mention it for the mouse or did you forget it?
#
#     Developing Mouse
#     G) How many sections does the E11.5 atlas have and at what intervals? How about E13.5 and P14?
#     H) Why these differences in the number of sections? Why such variation in the intervals?
#
#     Mouse Spinal Cord
#     I) How long are the intervals between sections in this case (in μm)? Why is that?
#
# <font size='3'> Keeping this kind of perspective and common sense is very valuable when looking at datasets

# %%
answers['brain_atlases_A'] = 0
answers['brain_atlases_B'] = 'Keep it short! Two sentences max'
answers['brain_atlases_C'] = 'Keep it short! Two sentences max'

answers['brain_atlases_D'] = (0, 0)
answers['brain_atlases_E'] = '__________ differences and ___ differences [...]. ___ is of course a factor as well'
answers['brain_atlases_F'] = 'Tissue _____________'

answers['brain_atlases_G'] = ('__ at __ μm', '__ at __ μm', '__ at __ μm')
answers['brain_atlases_H'] = 'Keep it short! Two sentences max'

answers['brain_atlases_I'] = (0, 'Write your reply here')

# %%
correct_answers['brain_atlases_A'] = 1675
correct_answers['brain_atlases_B'] = 'To correct for individual differences, tissue shrinkage, etc... and achieve a more robust average brain representation'
correct_answers['brain_atlases_C'] = 'It is an ideal average mouse, things in reality are not so clean. You need to quantify differences/re-align when comparing with experiments'

correct_answers['brain_atlases_D'] = (1, 34)
correct_answers['brain_atlases_E'] = 'Individual differences and sex differences [...]. Age is of course a factor as well'
correct_answers['brain_atlases_F'] = 'Tissue shrinkage'

correct_answers['brain_atlases_G'] = ('28 at 40 μm', '15 at 100 μm', '39 at 125 μm')
correct_answers['brain_atlases_H'] = 'More sections and shorter intervals = smaller brain or higher interest. Some development stages are more commonly used in experiments, a larger brain requires more sections or intervals get bigger'

correct_answers['brain_atlases_I'] = (2000, 'It is a spinal cord! It is long!')

# %% [markdown]
# ## Ex2.4. Cell atlases
#
# <font size='3'> Go to the [Blue Brain Cell Atlas](https://bbp.epfl.ch/nexus/cell-atlas/) and answer the following questions:
#
#     A) What is the ratio of excitatory to inhibitory neurons in the claustrum?
#     B) Can you find a brain region with no excitatory cells?
#     C) What is the total volume of the periaqueductal gray (in mm3)? And of the locus ceruleus?
#     D) What is the ratio between neurons and glia in the substantia innominata?
#
# <font size='3'> Now go to [MouseLight Neuron Browser](http://ml-neuronbrowser.janelia.org/) and continue with these:
#
#     E) How many available axons originating in the midbrain pass through the corpus callosum?
#     F) How many available cells project to the main olfactory bulb from outside the olfactory areas?
#     G) In which brain region is neuron AA1079?
#     H) Search the area around neuron AA1079 in a radius of 1.5 mm, how many neighbouring neurons can you find?

# %%
answers['cell_atlases_A'] = 0                      # use round(n, 4) to avoid gazillion decimals
answers['cell_atlases_B'] = 'brain_region'
answers['cell_atlases_C'] = (0, 0)
answers['cell_atlases_D'] = 0                      # use round(n, 4) to avoid gazillion decimals

answers['cell_atlases_E'] = 0
answers['cell_atlases_F'] = 0
answers['cell_atlases_G'] = 'brain_region'
answers['cell_atlases_H'] = 0

# %%
correct_answers['cell_atlases_A'] = round(32662/28479, 4)
correct_answers['cell_atlases_B'] = 'substantia innominata (there may be others, like internal capsule)'
correct_answers['cell_atlases_C'] = (5.17, 0.05)
correct_answers['cell_atlases_D'] = round(42929/155128, 4)

correct_answers['cell_atlases_E'] = 3
correct_answers['cell_atlases_F'] = (13, 'from logical query of axon end-point in MOB and soma NOT in olfactory areas', 'using axon instead gives 16, which we can also accept')
correct_answers['cell_atlases_G'] = 'arbor vitae'
correct_answers['cell_atlases_H'] = (6, 'someone might say 7 counting the central neuron')

# %% [markdown]
# ## Ex2.5. Explore data in 3D and produce an image
#
# <font size='3'> To conclude the exercise go to the [Allen Brain Explorer](http://connectivity.brain-map.org/3d-viewer) and take a single screenshot showing:
#
#     - Your favourite injection experiment going from the olfactory areas to the cerebellum, change the colour to blue
#     - The isocortex and cerebellar cortex. Choose the camera angle that looks best to you
#
# <font size='3'> Write the experiment ID below and attach the screenshot in your email together with your notebook. Try to paste the screenshot in a markdown cell to display it here, but don't stress if you can't or it does not save.

# %%
answers['screenshot_experiment_ID'] = 0

# %%
correct_answers['screenshot_experiment_ID'] = 184259031

# %% [markdown]
# ![Capture.JPG](attachment:ab03e514-912d-4100-9d89-bac6f5be8e65.JPG)

# %% [markdown]
# ## <font color= 'red'>Correction</font>
#
# <font color= 'red'>6 pts</font> maximum:
#   - <font color= 'red'>5 pts</font> from questions, all questions are equal
#   - <font color= 'red'>1 pts</font> for the screenshot

# %% [markdown]
# #### Python practice
# The exercise is over, but have a look at the correction function below. Grading here is done by displaying only those answers that are not == and counting mistakes

# %%
from colorama import Fore

def compare_answers(first, second):
    assert first.keys() == second.keys(), f'Question labels have been changed'
    for key in first.keys():
        if first[key] != second[key]:
            print(Fore.BLACK + '{}  |  '.format(key)    +
                  Fore.RED   + '{}'.format(first[key])  +
                  Fore.BLACK + '  |  '                  +
                  Fore.GREEN + '{}'.format(second[key]) )
    return

# %% [markdown]
# <font size="3" color="red"> --> Copy the correct answers dictionary here <--

# %%
correct_answers = {
 'morphologies_A': (33, 'cerebellum'),
 'morphologies_B': (1, True),
 'morphologies_C':  ('(151, 810) with keyword search and CA* wildcard','(151, 203) with keyword search only','(48, 81) with metadata multiple selection','(140,191) with API','we accept all values, the point is to show that query strategy matters and interacting with datasets is not straightforward'),
 'morphologies_D': (7029 + 11633, 7029),
 'morphologies_E': (5, False),
 'morphologies_F': (False, True),
 'morphologies_G': (203, 'CA* includes other text fields unrelated with the hippocampus', 'other ok values include 81, 191 (see 1C), again this answer is considered correct whatever the strategy'),
 'ion_channels_A': 'Temperature! It greatly affects results',
 'ion_channels_B': 'It is core body temperature ~[36, 36.5] C. Have a look at https://doi.org/10.1007/s10544-015-0028-9',
 'brain_atlases_A': 1675,
 'brain_atlases_B': 'To correct for individual differences, tissue shrinkage, etc... and achieve a more robust average brain representation',
 'brain_atlases_C': 'It is an ideal average mouse, things in reality are not so clean. You need to quantify differences/re-align when comparing with experiments',
 'brain_atlases_D': (1, 34),
 'brain_atlases_E': 'Individual differences and sex differences [...]. Age is of course a factor as well',
 'brain_atlases_F': 'Tissue shrinkage',
 'brain_atlases_G': ('28 at 40 μm', '15 at 100 μm', '39 at 125 μm'),
 'brain_atlases_H': 'More sections and shorter intervals = smaller brain or higher interest. Some development stages are more commonly used in experiments, a larger brain requires more sections or intervals get bigger',
 'brain_atlases_I': (2000, 'It is a spinal cord! It is long!'),
 'cell_atlases_A': round(32662/28479, 4),
 'cell_atlases_B': 'substantia innominata (there may be others, e.g. internal capsule)',
 'cell_atlases_C': (5.17, 0.05),
 'cell_atlases_D': round(42929/155128, 4),
 'cell_atlases_E': 3,
 'cell_atlases_F': (13, 'from logical query of axon end-point in MOB and soma NOT in olfactory areas', 'using axon instead gives 16, which we can also accept'),
 'cell_atlases_G': 'arbor vitae',
 'cell_atlases_H': (6, 'someone might say 7 counting the central neuron'),
 'screenshot_experiment_ID': 184259031 }

# %%
max_points  = 5
n_questions = len(correct_answers.keys())
compare_answers(answers, correct_answers)

#  TAs CHANGE THIS
#-------------------\
screenshot = True   #
n_mistakes = 4.5    # every wrong answer +1 mistake, partially correct tuples +0.5
#-------------------|

score = round(max_points * (n_questions - n_mistakes) / n_questions, 1) + screenshot
print(Fore.BLUE + '\n\n--->  The score for  | {} |  is {} points  <---'.format(student_names, score))
# Out:
# morphologies_A  |  (0, 'brain_region')  |  (33, 'cerebellum')
# morphologies_B  |  (0, True)  |  (1, True)
# morphologies_C  |  (0, 0)  |  ('(151, 810) with keyword search and CA* wildcard', '(151, 203) with keyword search only', '(48, 81) with metadata multiple selection', '(140,191) with API', 'we accept all values, the point is to show that query strategy matters and interacting with datasets is not straightforward')
# morphologies_D  |  (0, 0)  |  (18662, 7029)
# morphologies_E  |  (0, True)  |  (5, False)
# morphologies_F  |  (True, True)  |  (False, True)
# morphologies_G  |  (0, 'Write your reply here')  |  (203, 'CA* includes other text fields unrelated with the hippocampus', 'other ok values include 81, 191 (see 1C), again this answer is considered correct whatever the strategy')
# ion_channels_A  |  Write your reply here  |  Temperature! It greatly affects results
# ion_channels_B  |  Write your reply here  |  It is core body temperature ~[36, 36.5] C. Have a look at https://doi.org/10.1007/s10544-015-0028-9
# brain_atlases_A  |  0  |  1675
# brain_atlases_B  |  Keep it short! Two sentences max  |  To correct for individual differences, tissue shrinkage, etc... and achieve a more robust average brain representation
# brain_atlases_C  |  Keep it short! Two sentences max  |  It is an ideal average mouse, things in reality are not so clean. You need to quantify differences/re-align when comparing with experiments
# brain_atlases_D  |  (0, 0)  |  (1, 34)
# brain_atlases_E  |  __________ differences and ___ differences [...]. ___ is of course a factor as well  |  Individual differences and sex differences [...]. Age is of course a factor as well
# brain_atlases_F  |  Tissue _____________  |  Tissue shrinkage
# brain_atlases_G  |  ('__ at __ μm', '__ at __ μm', '__ at __ μm')  |  ('28 at 40 μm', '15 at 100 μm', '39 at 125 μm')
# brain_atlases_H  |  Keep it short! Two sentences max  |  More sections and shorter intervals = smaller brain or higher interest. Some development stages are more commonly used in experiments, a larger brain requires more sections or intervals get bigger
# brain_atlases_I  |  (0, 'Write your reply here')  |  (2000, 'It is a spinal cord! It is long!')
# cell_atlases_A  |  0  |  1.1469
# cell_atlases_B  |  brain_region  |  substantia innominata (there may be others, e.g. internal capsule)
# cell_atlases_C  |  (0, 0)  |  (5.17, 0.05)
# cell_atlases_D  |  0  |  0.2767
# cell_atlases_E  |  0  |  3
# cell_atlases_F  |  0  |  (13, 'from logical query of axon end-point in MOB and soma NOT in olfactory areas', 'using axon instead gives 16, which we can also accept')
# cell_atlases_G  |  brain_region  |  arbor vitae
# cell_atlases_H  |  0  |  (6, 'someone might say 7 counting the central neuron')
# screenshot_experiment_ID  |  0  |  184259031
#
#
# --->  The score for  | Group 0: John, Alice, Bob |  is 5.2 points  <---
